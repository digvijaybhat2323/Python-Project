# %%
import pandas as pd

# %%
df= pd.read_csv('C:\\Users\\kanti\\OneDrive\\Desktop\\class data\\rf\\diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df1 = pd.read_json('https://api.sampleapis.com/codingresources/codingResources')

# %%
df1
# Out:
#       id                                        description  \
# 0      1            South Florida's Best Meetups on Youtube
# 1      2  BocaJS - South Florida's Largest Developer Meetup
# 2      3                              Palm Beach Javascript
# 3      4      35 Useful CSS3 Tutorials To Boost Your Skills
# 4      5  5 more ways to start learning how to code righ...
# ..   ...                                                ...
# 168  169                    Udemy: Python Basics - Bootcamp
# 169  170                                     VIM Adventures
# 170  171  Visualgo - Animated visualizations for algorithms
# 171  172                                      w3schools.com
# 172  173  Write SwiftUI Entirely on an iPad Using Swift ...
#
#                                                    url  \
# 0                       https://www.youtube.com/bocajs
# 1                            https://Meetup.com/bocajs
# 2                https://www.youtube.com/palm-beach-js
# ...

# %%
df3 = pd.read_json('https://api.coindesk.com/v1/bpi/currentprice.json')

# %%
df3
# Out:
#                                  time  \
# updated     Feb 23, 2023 14:56:00 UTC
# updatedISO  2023-02-23T14:56:00+00:00
# updateduk   Feb 23, 2023 at 14:56 GMT
# USD                               NaN
# GBP                               NaN
# EUR                               NaN
#
#                                                    disclaimer chartName  \
# updated     This data was produced from the CoinDesk Bitco...   Bitcoin
# updatedISO  This data was produced from the CoinDesk Bitco...   Bitcoin
# updateduk   This data was produced from the CoinDesk Bitco...   Bitcoin
# USD         This data was produced from the CoinDesk Bitco...   Bitcoin
# GBP         This data was produced from the CoinDesk Bitco...   Bitcoin
# EUR         This data was produced from the CoinDesk Bitco...   Bitcoin
#
#                                                           bpi
# updated                                                   NaN
# updatedISO                                                NaN
# ...

# %%
df3['bpi']['USD']['rate']
#pd['column']['rows']['key']
# Out:
# '24,035.6947'

# %%
df3

# %%
df3['bpi']['GBP']['rate']
# Out:
# '20,084.0342'

# %%
df3['bpi']['EUR']['rate']
# Out:
# '23,414.2758'

# %%
df1 =df

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df1['new'] = 100

# %%
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  new
# 0                       0.627   50        1  100
# ...

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  new
# 0                       0.627   50        1  100
# ...

# %%
df3.loc[0,'chartName']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
type(df3.loc['updated','chartName'])
# Out:
# str

# %%
df3
# Out:
#                                  time  \
# updated     Feb 23, 2023 14:56:00 UTC
# updatedISO  2023-02-23T14:56:00+00:00
# updateduk   Feb 23, 2023 at 14:56 GMT
# USD                               NaN
# GBP                               NaN
# EUR                               NaN
#
#                                                    disclaimer chartName  \
# updated     This data was produced from the CoinDesk Bitco...   Bitcoin
# updatedISO  This data was produced from the CoinDesk Bitco...   Bitcoin
# updateduk   This data was produced from the CoinDesk Bitco...   Bitcoin
# USD         This data was produced from the CoinDesk Bitco...   Bitcoin
# GBP         This data was produced from the CoinDesk Bitco...   Bitcoin
# EUR         This data was produced from the CoinDesk Bitco...   Bitcoin
#
#                                                           bpi
# updated                                                   NaN
# updatedISO                                                NaN
# ...

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 10B6-0DC8
#
#  Directory of C:\Users\kanti\OneDrive\Desktop\ML session
#
# 23/02/2023  20:35    <DIR>          .
# 23/02/2023  20:13    <DIR>          ..
# 23/02/2023  20:04    <DIR>          .ipynb_checkpoints
# 19/02/2023  21:24               114 .jovianrc
# 19/02/2023  11:13           377.527 Advance Excel file Tool Base.xlsx
# 29/09/2019  08:41           938.020 Bengaluru_House_Data.csv
# 17/09/2022  07:08       140.600.832 city_temperature.csv
# 19/02/2023  21:22            11.507 covid_data.csv
# 19/02/2023  20:52         1.558.612 Data_final_pivot_table.xlsx
# 22/02/2023  21:09               132 hadling_missing.csv
# 22/02/2023  21:52        16.549.847 Pandas 1 to 4.zip
# 21/02/2023  21:44            78.283 Pandas 1.ipynb
# 20/02/2023  21:33           282.869 Pandas 2.ipynb
# 21/02/2023  21:43           251.184 Pandas 3.ipynb
# 22/02/2023  21:42           143.235 Pandas 4.ipynb
# ...

# %%
df = pd.read_csv('city_temperature.csv')
# Out:
# C:\Users\kanti\AppData\Local\Temp\ipykernel_15128\3433192447.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('city_temperature.csv')

# %%
df
# Out:
#                 Region  Country                   State                  City  \
# 0               Africa  Algeria                     NaN               Algiers
# 1               Africa  Algeria                     NaN               Algiers
# 2               Africa  Algeria                     NaN               Algiers
# 3               Africa  Algeria                     NaN               Algiers
# 4               Africa  Algeria                     NaN               Algiers
# ...                ...      ...                     ...                   ...
# 2906322  North America       US  Additional Territories  San Juan Puerto Rico
# 2906323  North America       US  Additional Territories  San Juan Puerto Rico
# 2906324  North America       US  Additional Territories  San Juan Puerto Rico
# 2906325  North America       US  Additional Territories  San Juan Puerto Rico
# 2906326  North America       US  Additional Territories  San Juan Puerto Rico
#
# ...

# %%
obj = df.groupby('Region')

# %%
#select * from city_temp groupby region 
obj.get_group('Africa')
# Out:
#         Region  Country State     City  Month  Day  Year  AvgTemperature
# 0       Africa  Algeria   NaN  Algiers      1    1  1995            64.2
# 1       Africa  Algeria   NaN  Algiers      1    2  1995            49.4
# 2       Africa  Algeria   NaN  Algiers      1    3  1995            48.8
# 3       Africa  Algeria   NaN  Algiers      1    4  1995            46.4
# 4       Africa  Algeria   NaN  Algiers      1    5  1995            47.9
# ...        ...      ...   ...      ...    ...  ...   ...             ...
# 251113  Africa   Zambia   NaN   Lusaka      1   18  2014            71.3
# 251114  Africa   Zambia   NaN   Lusaka      1   19  2014            77.5
# 251115  Africa   Zambia   NaN   Lusaka      1   20  2014            73.4
# 251116  Africa   Zambia   NaN   Lusaka      1   21  2014            73.1
# 251117  Africa   Zambia   NaN   Lusaka      1   22  2014            71.3
#
# [251118 rows x 8 columns]

# %%
obj.min()
# Out:
# C:\Users\kanti\AppData\Local\Temp\ipykernel_15128\3119354513.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   obj.min()
#                                       Country         City  Month  Day  Year  \
# Region
# Africa                                Algeria      Abidjan      1    0   201
# Asia                               Bangladesh       Almaty      1    1  1995
# Australia/South Pacific             Australia     Auckland      1    1  1995
# Europe                                Albania    Amsterdam      1    1   200
# Middle East                           Bahrain    Abu Dhabi      1    1  1995
# North America                          Canada      Abilene      1    0   201
# South/Central America & Carribean   Argentina  Belize City      1    0  1995
#
#                                    AvgTemperature
# Region
# ...

# %%
obj.max()
# Out:
# C:\Users\kanti\AppData\Local\Temp\ipykernel_15128\592755703.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   obj.max()
#                                                 Country         City  Month  \
# Region
# Africa                                           Zambia     Windhoek     12
# Asia                                            Vietnam    Vientiane     12
# Australia/South Pacific                     New Zealand       Sydney     12
# Europe                                       Yugoslavia       Zurich     12
# Middle East                        United Arab Emirates     Tel Aviv     12
# North America                                        US         Yuma     12
# South/Central America & Carribean             Venezuela  Tegucigalpa     12
#
#                                    Day  Year  AvgTemperature
# ...

# %%
obj.describe()
# Out:
#                                        Month                                \
#                                        count      mean       std  min  25%
# Region
# Africa                              251118.0  6.474757  3.458220  1.0  3.0
# Asia                                316663.0  6.469856  3.456514  1.0  3.0
# Australia/South Pacific              55596.0  6.468919  3.457171  1.0  3.0
# Europe                              381990.0  6.471363  3.457737  1.0  3.0
# Middle East                         124749.0  6.467106  3.455791  1.0  3.0
# North America                      1556681.0  6.467540  3.456167  1.0  3.0
# South/Central America & Carribean   219530.0  6.470678  3.454850  1.0  3.0
#
#                                                          Day             ...  \
#                                    50%  75%   max      count       mean  ...
# Region                                                                   ...
# ...

# %%
df
# Out:
#                 Region  Country                   State                  City  \
# 0               Africa  Algeria                     NaN               Algiers
# 1               Africa  Algeria                     NaN               Algiers
# 2               Africa  Algeria                     NaN               Algiers
# 3               Africa  Algeria                     NaN               Algiers
# 4               Africa  Algeria                     NaN               Algiers
# ...                ...      ...                     ...                   ...
# 2906322  North America       US  Additional Territories  San Juan Puerto Rico
# 2906323  North America       US  Additional Territories  San Juan Puerto Rico
# 2906324  North America       US  Additional Territories  San Juan Puerto Rico
# 2906325  North America       US  Additional Territories  San Juan Puerto Rico
# 2906326  North America       US  Additional Territories  San Juan Puerto Rico
#
# ...

# %%
df_age = df.groupby('Age')

# %%
df_age.get_group(50).sum()
# Out:
# Pregnancies                   54.000
# Glucose                     1106.000
# BloodPressure                626.000
# SkinThickness                128.000
# Insulin                      211.000
# BMI                          249.800
# DiabetesPedigreeFunction       3.761
# Age                          400.000
# Outcome                        5.000
# dtype: float64

# %%
df_age.count()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# Age
# 21            63       63             63             63       63   63
# 22            72       72             72             72       72   72
# 23            38       38             38             38       38   38
# 24            46       46             46             46       46   46
# 25            48       48             48             48       48   48
# 26            33       33             33             33       33   33
# 27            32       32             32             32       32   32
# 28            35       35             35             35       35   35
# 29            29       29             29             29       29   29
# 30            21       21             21             21       21   21
# 31            24       24             24             24       24   24
# 32            16       16             16             16       16   16
# ...

# %%
df_new = df_age.get_group(21)

# %%
df_new.max()
# Out:
# Pregnancies                   4.000
# Glucose                     177.000
# BloodPressure                96.000
# SkinThickness                50.000
# Insulin                     480.000
# BMI                          43.500
# DiabetesPedigreeFunction      1.731
# Age                          21.000
# Outcome                       1.000
# dtype: float64

# %%
dataset 


product copper  -- 3 DA

iron - 2DA

alumina 2DA

# %%
#concat

# %%
df --> df1

similar col  --> additional rows add
different col --> additional col add

# %%
pune_emp = {
    'id':[45,96,75,78],
    'name':['ketan','rahul','sunil','mukesh'],
    'sal':[7500,95500,94949,194949]
}

# %%
df = pd.DataFrame(pune_emp)

# %%
df
# Out:
#    id    name     sal
# 0  45   ketan    7500
# 1  96   rahul   95500
# 2  75   sunil   94949
# 3  78  mukesh  194949

# %%
bang_emp = {
    'id':[45,200,300,400],
    'name':['ketan','sohel','anand','rohit'],
    'sal':[95000,795995,164949,97979797]
}

# %%
df1 = pd.DataFrame(bang_emp)

# %%
df1
# Out:
#     id   name       sal
# 0   45  ketan     95000
# 1  200  sohel    795995
# 2  300  anand    164949
# 3  400  rohit  97979797

# %%
df
# Out:
#    id    name     sal
# 0  45   ketan    7500
# 1  96   rahul   95500
# 2  75   sunil   94949
# 3  78  mukesh  194949

# %%
df_concat = pd.concat([df,df1],axis=0)

# %%
df_concat
# Out:
#     id    name       sal
# 0   45   ketan      7500
# 1   96   rahul     95500
# 2   75   sunil     94949
# 3   78  mukesh    194949
# 0   45   ketan     95000
# 1  200   sohel    795995
# 2  300   anand    164949
# 3  400   rohit  97979797

# %%
df_concat = pd.concat([df,df1],axis=0,keys=['df','df1'])

# %%
df_concat
# Out:
#         id    name       sal
# df  0   45   ketan      7500
#     1   96   rahul     95500
#     2   75   sunil     94949
#     3   78  mukesh    194949
# df1 0   45   ketan     95000
#     1  200   sohel    795995
#     2  300   anand    164949
#     3  400   rohit  97979797

# %%
details = {
    'aadhar':[119191,161,961919,None],
    'pan':['sdfsdf','adfsasdf','asdfsdf','asdfsdf']
}

# %%
df2=pd.DataFrame(details)

# %%
details
# Out:
# {'aadhar': [119191, 161, 961919, None],
#  'pan': ['sdfsdf', 'adfsasdf', 'asdfsdf', 'asdfsdf']}

# %%
df_add_details_added = pd.concat([df,df2],axis=1)

# %%
df_add_details_added
# Out:
#    id    name     sal    aadhar       pan
# 0  45   ketan    7500  119191.0    sdfsdf
# 1  96   rahul   95500     161.0  adfsasdf
# 2  75   sunil   94949  961919.0   asdfsdf
# 3  78  mukesh  194949       NaN   asdfsdf

# %%
pd.concat([df,df1.iloc[2:4,:]])
# Out:
#     id    name       sal
# 0   45   ketan      7500
# 1   96   rahul     95500
# 2   75   sunil     94949
# 3   78  mukesh    194949
# 2  300   anand    164949
# 3  400   rohit  97979797

# %%
sql -- table --> contraints

# %%
df_concat.loc['df']
# Out:
#    id    name     sal
# 0  45   ketan    7500
# 1  96   rahul   95500
# 2  75   sunil   94949
# 3  78  mukesh  194949

# %%
df_concat
#multi index df
# Out:
#         id    name       sal
# df  0   45   ketan      7500
#     1   96   rahul     95500
#     2   75   sunil     94949
#     3   78  mukesh    194949
# df1 0   45   ketan     95000
#     1  200   sohel    795995
#     2  300   anand    164949
#     3  400   rohit  97979797

# %%
df_concat.loc['df1'].iloc[1:3]
# Out:
#     id   name     sal
# 1  200  sohel  795995
# 2  300  anand  164949

# %%
df
# Out:
#    id    name     sal
# 0  45   ketan    7500
# 1  96   rahul   95500
# 2  75   sunil   94949
# 3  78  mukesh  194949

# %%
#how to add new col with series

d = pd.Series(['pune','mumbai','pune'],name='city')

# %%
d
# Out:
# 0      pune
# 1    mumbai
# 2      pune
# Name: city, dtype: object

# %%
df_with_series = pd.concat([df,d],axis=1)

# %%
df_with_series
# Out:
#    id    name     sal    city
# 0  45   ketan    7500    pune
# 1  96   rahul   95500  mumbai
# 2  75   sunil   94949    pune
# 3  78  mukesh  194949     NaN

# %%
df12 = pd.concat([df,df_add_details_added.pan],axis=1)

# %%
df12
# Out:
#    id    name     sal       pan
# 0  45   ketan    7500    sdfsdf
# 1  96   rahul   95500  adfsasdf
# 2  75   sunil   94949   asdfsdf
# 3  78  mukesh  194949   asdfsdf

# %%
#merge

# %%
df
# Out:
#    id    name     sal
# 0  45   ketan    7500
# 1  96   rahul   95500
# 2  75   sunil   94949
# 3  78  mukesh  194949

# %%
department = {
    'id':[45,100,950,75,690,78],
    'dept_name':['IT','Admin','HR','Fin','Market','Support']
}

# %%
department
# Out:
# {'id': [45, 100, 950, 75, 690, 78],
#  'dept_name': ['IT', 'Admin', 'HR', 'Fin', 'Market', 'Support']}

# %%
dept = pd.DataFrame(department)

# %%
dept
# Out:
#     id dept_name
# 0   45        IT
# 1  100     Admin
# 2  950        HR
# 3   75       Fin
# 4  690    Market
# 5   78   Support

# %%
df
# Out:
#    id    name     sal
# 0  45   ketan    7500
# 1  96   rahul   95500
# 2  75   sunil   94949
# 3  78  mukesh  194949

# %%
#for merge -- common col

# %%
df
# Out:
#    id    name     sal
# 0  45   ketan    7500
# 1  96   rahul   95500
# 2  75   sunil   94949
# 3  78  mukesh  194949

# %%
pd.merge(df,dept,on='id',how='inner')
# Out:
#    id    name     sal dept_name
# 0  45   ketan    7500        IT
# 1  75   sunil   94949       Fin
# 2  78  mukesh  194949   Support

# %%
#inner join --> common --matched records

# %%
pd.merge(df,dept,on='id',how='left')
# Out:
#    id    name     sal dept_name
# 0  45   ketan    7500        IT
# 1  96   rahul   95500       NaN
# 2  75   sunil   94949       Fin
# 3  78  mukesh  194949   Support

# %%
pd.merge(df,dept,on='id',how='outer')
# Out:
#     id    name       sal dept_name
# 0   45   ketan    7500.0        IT
# 1   96   rahul   95500.0       NaN
# 2   75   sunil   94949.0       Fin
# 3   78  mukesh  194949.0   Support
# 4  100     NaN       NaN     Admin
# 5  950     NaN       NaN        HR
# 6  690     NaN       NaN    Market

# %%
Assigment:
    -- excel --> sheet1,sheet2,sheet3
    
    df -- sheet1+sheet2+sheet3
